# %%
import requests
import pandas as pd
import logging as lg

lg.basicConfig(level=lg.INFO)
# Out:
# StatementMeta(, a14a41c0-9077-41c6-acd9-66b167f5aa2c, 3, Finished, Available, Finished)

# %%
# par_datepart='2025-01'
par_url='https://d37ci6vzurychx.cloudfront.net'
par_filename='yellow_tripdata'
par_directory ='trip-data'
par_actual_url=f"{par_url}/{par_directory}/{par_filename}_{par_datepart}.parquet"
par_output_path = f"Files/newyork-data/yellow_taxi_data_{par_datepart}/"
# Out:
# StatementMeta(, a14a41c0-9077-41c6-acd9-66b167f5aa2c, 4, Finished, Available, Finished)

# %%
def download_taxi_data(url,output_path):

    try:
        # filename = url.split('/')[-1]
        r = requests.get(url)
        with open("temp.parquet", "wb") as f:
            f.write(r.content)

        df = pd.read_parquet("temp.parquet")

        spark_df = spark.createDataFrame(df)


        spark_df.repartition(1).write.format('parquet')\
                                      .mode('overwrite')\
                                      .save(output_path)   

        lg.info(f'{url} file is downloaded')


    except Exception as e:
        lg.info(f"Error in download_taxi_data function {e}")
# Out:
# StatementMeta(, a14a41c0-9077-41c6-acd9-66b167f5aa2c, 5, Finished, Available, Finished)

# %%
def main():
    download_taxi_data(par_actual_url,par_output_path )
# Out:
# StatementMeta(, a14a41c0-9077-41c6-acd9-66b167f5aa2c, 6, Finished, Available, Finished)

# %%
if __name__ == '__main__':
    main()
# Out:
# StatementMeta(, a14a41c0-9077-41c6-acd9-66b167f5aa2c, 7, Finished, Available, Finished)
# INFO:root:https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-01.parquet file is downloaded
